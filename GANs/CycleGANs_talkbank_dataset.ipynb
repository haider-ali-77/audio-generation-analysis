# %%
# !git clone https://github.com/jackaduma/CycleGAN-VC2.git
# Out:
# Cloning into 'CycleGAN-VC2'...
# remote: Enumerating objects: 92, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 544 (delta 53), reused 58 (delta 24), pack-reused 452
# Receiving objects: 100% (544/544), 87.06 MiB | 20.67 MiB/s, done.
# Resolving deltas: 100% (62/62), done.
# Checking out files: 100% (428/428), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/drive/MyDrive/RevolveAI/AltusVox/cmu_us_bdl_arctic_wav/ /content/drive/MyDrive/RevolveAI/AltusVox/CycleGAN-VC2/data/

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 225kB 16.9MB/s
# ...
#   Created wheel for pyworld: filename=pyworld-0.2.12-cp36-cp36m-linux_x86_64.whl size=609666 sha256=48d201600656b0a8a41f09d41d23d73b57532f97051385c5bcafb798ff3e44be
#   Stored in directory: /root/.cache/pip/wheels/d0/e4/1c/a508000462b83164d5eba9a4b46f39b4b1645ac952bbe71551
# Successfully built pyworld
# ...

# %%
# %cd /content/drive/MyDrive/RevolveAI/AltusVox/CycleGAN-VC2/
# Out:
# /content/drive/MyDrive/RevolveAI/AltusVox/CycleGAN-VC2

# %%
# Out:
# CycleGAN-VC2/  drive/  sample_data/

# %%
# %cd CycleGAN-VC2
# !python preprocess_training.py --train_A_dir ./data/data_talkbank_callhome_4065_wav/ --train_B_dir ./data/cmu_us_bdl_arctic_wav/ --cache_folder ./cache/
# Out:
# Starting to prepocess data.......
# Log Pitch A
# Mean: 5.2942, Std: 0.2304
# Log Pitch B
# Mean: 4.8362, Std: 0.2114
# Preprocessing finsihed!! see your directory ../cache for cached preprocessed data
# Time taken for preprocessing 2681.6877 seconds

# %%
# !python train.py --logf0s_normalization ./cache/logf0s_normalization.npz --mcep_normalization ./cache/mcep_normalization.npz --coded_sps_A_norm ./cache/coded_sps_A_norm.pickle --coded_sps_B_norm ./cache/coded_sps_B_norm.pickle --model_checkpoint ./model_checkpoint/ --resume_training_at ./model_checkpoint/_CycleGAN_CheckPoint --validation_A_dir ./data/data_talkbank_callhome_4065_wav/ --output_A_dir ./converted_sound/data_talkbank_callhome_4065_wav --validation_B_dir ./data/gaoxiaosong/ --output_B_dir ./converted_sound/gaoxiaosong/
# !python train.py --logf0s_normalization ./cache/logf0s_normalization.npz --mcep_normalization ./cache/mcep_normalization.npz --coded_sps_A_norm ./cache/coded_sps_A_norm.pickle --coded_sps_B_norm ./cache/coded_sps_B_norm.pickle --model_checkpoint ./model_checkpoint/ --resume_training_at ./model_checkpoint/_CycleGAN_CheckPoint --validation_A_dir ./data/data_talkbank_callhome_4065_wav/ --output_A_dir ./converted_sound/data_talkbank_callhome_4065_wav --validation_B_dir ./data/cmu_us_bdl_arctic_wav/ --output_B_dir ./converted_sound/cmu_us_bdl_arctic_wav/
# Out:
# cuda
# Training resumed
# Epoch:112 Iter:31298 Generator Loss:6.8551 Discrimator Loss:0.1959 GA2B:0.4697 GB2A:0.4063 G_id:1.1818 G_cyc:0.5979 D_A:0.1398 D_B:0.2304: : 0it [01:07, ?it/s]Epoch: 112 Generator Loss: 7.4584 Discriminator Loss: 0.12397335469722748, Time: 67.89
#
#
# Saving model Checkpoint  ......
# Model Saved!
# Generating Validation Data B from A...
# /content/drive/My Drive/RevolveAI/AltusVox/CycleGAN-VC2/preprocess.py:118: RuntimeWarning: divide by zero encountered in log
#   std_log_src * std_log_target + mean_log_target)
# [-9.0626992e-05 -5.2020154e-05 -2.8224940e-06 ... -2.8819597e-04
#   3.1591079e-04 -2.7957314e-04]
# /content/drive/My Drive/RevolveAI/AltusVox/CycleGAN-VC2/preprocess.py:118: RuntimeWarning: divide by zero encountered in log
#   std_log_src * std_log_target + mean_log_target)
# [-1.6716690e-06 -6.8748687e-07  8.8477145e-07 ... -5.3093364e-03
#   7.1577448e-03 -4.7864821e-03]
# ...

# %%
# !cp -r /content/CycleGAN-VC2 /content/drive/MyDrive/RevolveAI/AltusVox/

# %%
# %cd /content/drive/MyDrive/RevolveAI/AltusVox/CycleGAN-VC2
# Out:
# /content/drive/MyDrive/RevolveAI/AltusVox/CycleGAN-VC2

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !python test.py
# Out:
# True
# cuda

# %%
# !apt install aria2
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libc-ares2
# The following NEW packages will be installed:
#   aria2 libc-ares2
# 0 upgraded, 2 newly installed, 0 to remove and 13 not upgraded.
# Need to get 1,274 kB of archives.
# After this operation, 4,912 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libc-ares2 amd64 1.14.0-1 [37.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 aria2 amd64 1.33.1-1 [1,236 kB]
# Fetched 1,274 kB in 1s (1,859 kB/s)
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 146374 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.14.0-1_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.14.0-1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.33.1-1_amd64.deb ...
# ...

# %%
# !aria2c https://www.itu.int/rec/dologin_pub.asp?lang=e&id=T-REC-G.729-201206-I!!SOFT-ZST-E&type=items
# Out:
# 01/22 07:39:42 [NOTICE] Downloading 1 item(s)
#
# 01/22 07:39:42 [ERROR] CUID#7 - Download aborted. URI=https://www.itu.int/rec/dologin_pub.asp?lang=e
# Exception: [AbstractCommand.cc:351] errorCode=22 URI=https://www.itu.int/rec/dologin_pub.asp?lang=e
#   -> [HttpSkipResponseCommand.cc:239] errorCode=22 The response status is not successful. status=500
#
# 01/22 07:39:42 [NOTICE] Download GID#dbf7002c3252370b not complete:
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# dbf700|ERR |       0B/s|https://www.itu.int/rec/dologin_pub.asp?lang=e
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
